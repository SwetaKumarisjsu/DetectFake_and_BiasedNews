# %%
import svm
import NaiveBayes
import NeuralNetwork

def main():
    NaiveBayes.NaiveBayes()
    svm.SVM()
    NeuralNetwork.NN()

if __name__ == "__main__":
    main()
# Out:
# Using TensorFlow backend.
# Naive Bayes model accuracy = 72.26%
# SVM model accuracy = 88.27%
# Epoch 1/20
# 13286/13286 [==============================] - 1s 80us/step - loss: 0.5271 - acc: 0.7488
# Epoch 2/20
# 13286/13286 [==============================] - 1s 51us/step - loss: 0.2900 - acc: 0.8818
# Epoch 3/20
# 13286/13286 [==============================] - 1s 44us/step - loss: 0.2618 - acc: 0.8931
# Epoch 4/20
# 13286/13286 [==============================] - 1s 44us/step - loss: 0.2383 - acc: 0.9037
# Epoch 5/20
# 13286/13286 [==============================] - 1s 44us/step - loss: 0.2243 - acc: 0.9111
# Epoch 6/20
# 13286/13286 [==============================] - 1s 47us/step - loss: 0.2110 - acc: 0.9173
# Epoch 7/20
# 13286/13286 [==============================] - 1s 47us/step - loss: 0.2021 - acc: 0.9197
# Epoch 8/20
# 13286/13286 [==============================] - 1s 45us/step - loss: 0.1924 - acc: 0.9243
# Epoch 9/20
# ...
